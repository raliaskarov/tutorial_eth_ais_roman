# %%
def play_yourself():
  """
  We simlate a blackjack game
  """

  # initialize the game
  game_over = False
  while not game_over:
    # take action

    # if hit, draw a card

    # update your state
